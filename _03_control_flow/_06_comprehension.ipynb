# %% [markdown]
# # Comprehension(이해력 이라는 뜻) 내포
#
# - Comprehension은 한 줄짜리 반복문으로 새로운 컬렉션을 만드는 문법이다.
# - 대표적으로 list comprehension과 dict comprehension이 있다.
# - 반복문으로 값을 하나씩 추가하는 패턴을 더 짧고 읽기 좋게 표현할 수 있다.
#
# - list comprehension
# ```
# # list 생성
# [표현식 for 변수 in 반복가능한객체]
#
# # 조건 포함
# [표현식 for 변수 in 반복가능한객체 if 조건식]
# ```
#
# - dict comprehension
# ```
# # dict 생성
# {key표현식: value표현식 for 변수 in 반복가능한객체}
#
# # 조건 포함
# {key표현식: value표현식 for 변수 in 반복가능한객체 if 조건식}
# ```

# %% [markdown]
# ## 1. for 반복문과 list comprehension 비교
#
# 먼저 일반 `for` 반복문으로 리스트를 만든 뒤, 같은 결과를 list comprehension으로 바꿔 본다.

# %%
# def make_numbers_with_for() -> list[int]:
#     numbers: list[int] = []
#     for n in range(1, 6): # 1~5까지
#         numbers.append(n)
#         return numbers # 들여쓰기 차이 -- 앞쪽으로 안보냈기 때문에 1을 append 하면 바로 종료되는 -> 앞쪽으로 써야
#
# print(make_numbers_with_for())

def make_numbers_with_for() -> list[int]:
    numbers: list[int] = []
    for n in range(1, 6):
        numbers.append(n)
    return numbers


print(make_numbers_with_for())

# list comprehension

def make_numbers_with_comprehension() -> list[int]:
    return [n*2 for n in range(1, 6)]

print(make_numbers_with_comprehension())
# Out:
# [1, 2, 3, 4, 5]
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## 2. 조건식이 있는 list comprehension
#
# `if` 조건을 붙이면 원하는 요소만 필터링해서 리스트를 만들 수 있다.

# %%
# 1~100 사이 정수 중 3의 배수 list 요소로 추가

def make_numbers3() -> list[int]:
    return [n for n in range(1, 101) if n % 3 == 0]
# 해석순서 / for n in range(1, 101) -> n for -> if n % ==0 -> for n in range

print('3의 배수 리스트 : ', make_numbers3())
# Out:
# 3의 배수 리스트 :  [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99]

# %%
# 전달된 list에서 정수(int) 타입만 필터링해서 반환

lst = [1, '123', '안녕', 22, {}, [], True, 333]

# object 타입 : 아무 타입이나 가능 (== Any)
def filter_int_values(values: list[object]) -> list[int]:
    # isinstance(value, type) -> bool
    # - value의 자료형이 type과 일치하면 True, 아니면 False
    return [v for v in values if isinstance(v, int)]

print(filter_int_values(lst)) # True == 1로 취급 및 변환되서 함께 출력
# Out:
# [1, 22, True, 333]

# %% [markdown]
# ## 3. 중첩 반복문 list comprehension
#
# 반복문이 중첩된 구조도 comprehension으로 표현할 수 있다. 다만 너무 복잡해지면 일반 반복문이 더 읽기 쉽다.

# %%
# 중첩 반복문

def make_positions() -> list[tuple[int, int]]:
    positions: list[tuple[int, int]] = []

    for row in range(3): # 0, 1, 2 / 행 == row
        for col in range(5): # 0, 1, 2, 3, 4 / 열 == column
            positions.append((row, col))

    return positions

print(make_positions())
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4)]

# %%
# 중첩 comprehension

def make_positions_with_comprehension() -> list[tuple[int, int]]:
    return [(row, col) for row in range(3) for col in range(5)]

print(make_positions_with_comprehension())
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4), (1, 0), (1, 1), (1, 2), (1, 3), (1, 4), (2, 0), (2, 1), (2, 2), (2, 3), (2, 4)]

# %% [markdown]
# ## 4. dict comprehension
#
# `dict`도 comprehension으로 만들 수 있다.
#
# ```python
# {key식: value식 for 요소 in iterable(반복 가능한 애들)}
# ```

# %%
def make_square_map() -> dict[int, int]: # 여가서의 spuare는 제곱을 의미
    return {k : k**2 for k in range(1, 6)}

print(make_square_map())
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# 문자열 리스트를 전달하여 '문자열' : 문자열길이 형태의 list[dict] 반환

def make_word_length_map(words : list[str]) -> dict[str , int]: #python dict == 다른언어 map
    # 일반적인 방법
    # result = {}
    # for word in words:
    #     result[word[0]] = len(word)
    # return result

    #comprehension 방법
    return {word : len(word) for word in words if len(word) > 10}

words = ['너는 몇 글자니', '반복문은 왜 이렇게 지랄맞은가', '비는 또 왜 오는가', 'ㅋ']
print(make_word_length_map(words))
# Out:
# {'반복문은 왜 이렇게 지랄맞은가': 16}

# %% [markdown]
# ## 5. list와 dict 변환
#
# `zip()`과 `dict()`를 함께 사용하면 두 리스트를 하나의 딕셔너리로 묶을 수 있다. 반대로 `dict.items()`와 unpacking을 사용하면 딕셔너리에서 key와 value 묶음을 분리할 수 있다.

# %%
def make_age_map() -> dict[str, int]:
    names : list[str] = ['홍박사님', '리순신', '세종대왕']
    ages :  list[int] = [44, 46, 32]
    zip(names, ages)

    # zip(names, ages) == ['홍박사님', '44' ~~~ ] 이런식으로 차례대로 결과값이 나옴
    return dict(zip(names, ages))

print('list -> dict : ', make_age_map())
# Out:
# list -> dict :  {'홍박사님': 44, '리순신': 46, '세종대왕': 32}

# %%
def split_age_map() -> tuple[tuple[str, ...], tuple[int, ...]]:
    info : dict[str, int] = {'홍길동':20, '신사임당':40, '이순신':30}
    print('info.items() : ', info.items()) # list[tuple]
    print(*info.items()) # * 기호 == 풀기

    names, ages = zip(*info.items())
    return names, ages

print('dict -> tuple 묶음 :', split_age_map())
# Out:
# info.items() :  dict_items([('홍길동', 20), ('신사임당', 40), ('이순신', 30)])
# ('홍길동', 20) ('신사임당', 40) ('이순신', 30)
# dict -> tuple 묶음 : (('홍길동', '신사임당', '이순신'), (20, 40, 30))
